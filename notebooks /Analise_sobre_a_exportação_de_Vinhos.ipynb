# %% [markdown]
# <a href="https://colab.research.google.com/github/icarocarmona/tech_challenge_f1/blob/main/notebooks%20/Analise_sobre_a_exporta%C3%A7%C3%A3o_de_Vinhos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/icarocarmona/tech_challenge_f1/main/dados/trusted/dados_de_vinhos.csv", sep=";" )
dados.head()
# Out:
#      Destino  Quantidade (L)  Valor U$   Ano  Origem  Tipo Vinho        Tipo
# 0  Outros(1)            5132      3208  1970  Brasil  Espumantes  Exportação
# 1   Paraguai             415       152  1970  Brasil  Espumantes  Exportação
# 2    Bolívia              36        24  1970  Brasil  Espumantes  Exportação
# 3     Vietnã               0         0  1970  Brasil  Espumantes  Exportação
# 4     Líbano               0         0  1970  Brasil  Espumantes  Exportação

# %%
dados.value_counts('Tipo Vinho')
# Out:
# Tipo Vinho
# Vinho De Mesa    6784
# Uvas             6731
# Sucos            6413
# Espumantes       5353
# dtype: int64

# %%
vinhos_de_mesa = dados[dados['Tipo Vinho'] == 'Vinho De Mesa'].reset_index(drop=True)
vinhos_de_mesa.head()
# Out:
#           Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 0        Paraguai           89846     23980  1970  Brasil  Vinho De Mesa
# 1        Colômbia           14205      6650  1970  Brasil  Vinho De Mesa
# 2  Estados Unidos           11200      4200  1970  Brasil  Vinho De Mesa
# 3        Tanzânia           13692      3562  1970  Brasil  Vinho De Mesa
# 4         Libéria            4160      1190  1970  Brasil  Vinho De Mesa
#
#          Tipo
# 0  Exportação
# 1  Exportação
# 2  Exportação
# 3  Exportação
# 4  Exportação

# %%
vinhos_de_mesa.shape
# Out:
# (6784, 7)

# %%
vinhos_de_mesa[['Destino', 'Quantidade (L)', 'Ano']]
# Out:
#              Destino  Quantidade (L)   Ano
# 0           Paraguai           89846  1970
# 1           Colômbia           14205  1970
# 2     Estados Unidos           11200  1970
# 3           Tanzânia           13692  1970
# 4            Libéria            4160  1970
# ...              ...             ...   ...
# 6779       Nicaragua               0  2022
# 6780  Nova Caledônia               0  2022
# 6781      Costa Rica               0  2022
# 6782        Honduras               0  2022
# 6783     Afeganistão               0  2022
#
# [6784 rows x 3 columns]

# %%
top_10_paises = vinhos_de_mesa.groupby(by='Destino')['Quantidade (L)'].sum().sort_values(ascending=False).head(10).index
top_10_paises
# Out:
# Index(['Paraguai', 'Estados Unidos', 'Rússia', 'Japão', 'Angola',
#        'Reino Unido', 'China', 'Espanha', 'Haiti', 'Países Baixos'],
#       dtype='object', name='Destino')

# %%
vinhos_de_mesa_filtrado = vinhos_de_mesa[vinhos_de_mesa['Destino'].isin(top_10_paises)]
vinhos_de_mesa_filtrado.head()
# Out:
#            Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 0         Paraguai           89846     23980  1970  Brasil  Vinho De Mesa
# 2   Estados Unidos           11200      4200  1970  Brasil  Vinho De Mesa
# 22   Países Baixos               0         0  1970  Brasil  Vinho De Mesa
# 27           Japão               0         0  1970  Brasil  Vinho De Mesa
# 58          Rússia               0         0  1970  Brasil  Vinho De Mesa
#
#           Tipo
# 0   Exportação
# 2   Exportação
# 22  Exportação
# 27  Exportação
# 58  Exportação

# %%
import seaborn as sns

# %%
sns.set_theme(style='dark')

sns.lineplot(data=vinhos_de_mesa_filtrado,
            x='Ano', y= 'Quantidade (L)', hue='Destino')
# Out:
# <Axes: xlabel='Ano', ylabel='Quantidade (L)'>

# %%
# filtrar apenas os dados de 2010 pra frente
vinhos_de_mesa_filtrado = vinhos_de_mesa_filtrado[vinhos_de_mesa_filtrado['Ano'] >= 2010]

# %%
sns.lineplot(data=vinhos_de_mesa_filtrado,
            x='Ano', y= 'Quantidade (L)', hue='Destino')
# Out:
# <Axes: xlabel='Ano', ylabel='Quantidade (L)'>

# %% [markdown]
# https://ainfo.cnptia.embrapa.br/digital/bitstream/item/130799/1/Comunicado-Tecnico-174.pdf
#
# Pelo que entendi no relatório a queda de 2014 deve pelo seguinte motivo:
#
# A quantidade de vinhos exportada em 2014 foi
# de 2,32 milhões de litros, representando uma
# redução de 74,60%. Essa redução aconteceu
# porque em 2013 o setor se beneficiou do Programa
# de Escoamento da Produção (PEPRO), pois havia
# vantagem competitiva no mercado internacional
# para adotá-lo, o que não ocorreu em 2014. As
# cooperativas participaram desse programa com
# a adesão de pequenos produtores de agricultura
# familiar. O escoamento foi feito com vinho a granel

# %%
sns.pairplot(vinhos_de_mesa_filtrado)

# %%
import matplotlib.pyplot as plt

# plt.figure(figsize=(5,10))
sns.lineplot(data=vinhos_de_mesa_filtrado, x='Ano', y='Valor U$', hue='Tipo Vinho')
# Out:
# <Axes: xlabel='Ano', ylabel='Valor U$'>

# %%
sns.lineplot(data=vinhos_de_mesa, x='Ano', y='Valor U$', hue='Tipo Vinho')
# Out:
# <Axes: xlabel='Ano', ylabel='Valor U$'>

# %%
df = vinhos_de_mesa[vinhos_de_mesa['Ano'] >= 2022]
# df.sort_values('Valor U$',ascending=False)


# rows_with_zeros = df[]
rows_with_zeros = (df == 0).any(axis=1)

df = df[~rows_with_zeros]
df
# Out:
#               Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 6656         Paraguai         5076670   7156293  2022  Brasil  Vinho De Mesa
# 6657          Uruguai          637117    997367  2022  Brasil  Vinho De Mesa
# 6658            Haiti          553503    741014  2022  Brasil  Vinho De Mesa
# 6659   Estados Unidos          220373    447893  2022  Brasil  Vinho De Mesa
# 6660            China          105395    404647  2022  Brasil  Vinho De Mesa
# ...               ...             ...       ...   ...     ...            ...
# 6727         Bulgária               5        31  2022  Brasil  Vinho De Mesa
# 6728           Suécia               5        18  2022  Brasil  Vinho De Mesa
# 6729  Guiana Francesa              22        18  2022  Brasil  Vinho De Mesa
# 6730        Dinamarca               2         6  2022  Brasil  Vinho De Mesa
# 6731             Cuba              16         6  2022  Brasil  Vinho De Mesa
#
#             Tipo
# 6656  Exportação
# 6657  Exportação
# 6658  Exportação
# 6659  Exportação
# 6660  Exportação
# ...          ...
# 6727  Exportação
# 6728  Exportação
# 6729  Exportação
# 6730  Exportação
# 6731  Exportação
#
# [76 rows x 7 columns]

# %%
df.mean()
# Out:
# <ipython-input-17-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Quantidade (L)     92447.144737
# Valor U$          144016.868421
# Ano                 2022.000000
# dtype: float64

# %%
df['vl_litro'] = df['Valor U$'] / df['Quantidade (L)']
df.head()
# Out:
#              Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 6656        Paraguai         5076670   7156293  2022  Brasil  Vinho De Mesa
# 6657         Uruguai          637117    997367  2022  Brasil  Vinho De Mesa
# 6658           Haiti          553503    741014  2022  Brasil  Vinho De Mesa
# 6659  Estados Unidos          220373    447893  2022  Brasil  Vinho De Mesa
# 6660           China          105395    404647  2022  Brasil  Vinho De Mesa
#
#             Tipo  vl_litro
# 6656  Exportação  1.409643
# 6657  Exportação  1.565438
# 6658  Exportação  1.338771
# 6659  Exportação  2.032431
# 6660  Exportação  3.839338

# %%
df = df.sort_values('vl_litro', ascending=False)
df.head(10)
# Out:
#                      Destino  Quantidade (L)  Valor U$   Ano  Origem  \
# 6719                 Áustria               6       212  2022  Brasil
# 6710              Luxemburgo              36       802  2022  Brasil
# 6663  Emirados Arabes Unidos            4781     85465  2022  Brasil
# 6671                 Noruega            2711     40316  2022  Brasil
# 6715                 Croácia              34       484  2022  Brasil
# 6679                   Suíça            1584     20863  2022  Brasil
# 6723              Bangladesh               7        84  2022  Brasil
# 6716        Taiwan (FORMOSA)              25       277  2022  Brasil
# 6684               Austrália            1424     12299  2022  Brasil
# 6685       Tcheca, República            1305      9997  2022  Brasil
#
#          Tipo Vinho        Tipo   vl_litro
# 6719  Vinho De Mesa  Exportação  35.333333
# 6710  Vinho De Mesa  Exportação  22.277778
# 6663  Vinho De Mesa  Exportação  17.875967
# 6671  Vinho De Mesa  Exportação  14.871265
# 6715  Vinho De Mesa  Exportação  14.235294
# 6679  Vinho De Mesa  Exportação  13.171086
# 6723  Vinho De Mesa  Exportação  12.000000
# 6716  Vinho De Mesa  Exportação  11.080000
# 6684  Vinho De Mesa  Exportação   8.636938
# 6685  Vinho De Mesa  Exportação   7.660536

# %%
df[df['Valor U$'] >= 100000]
# Out:
#              Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 6661     Reino Unido           18835    138154  2022  Brasil  Vinho De Mesa
# 6660           China          105395    404647  2022  Brasil  Vinho De Mesa
# 6659  Estados Unidos          220373    447893  2022  Brasil  Vinho De Mesa
# 6662          Rússia           66046    118618  2022  Brasil  Vinho De Mesa
# 6657         Uruguai          637117    997367  2022  Brasil  Vinho De Mesa
# 6656        Paraguai         5076670   7156293  2022  Brasil  Vinho De Mesa
# 6658           Haiti          553503    741014  2022  Brasil  Vinho De Mesa
#
#             Tipo  vl_litro
# 6661  Exportação  7.334962
# 6660  Exportação  3.839338
# 6659  Exportação  2.032431
# 6662  Exportação  1.795991
# 6657  Exportação  1.565438
# 6656  Exportação  1.409643
# 6658  Exportação  1.338771

# %%
df.sort_values('Valor U$', ascending=False).head(10)
# Out:
#                      Destino  Quantidade (L)  Valor U$   Ano  Origem  \
# 6656                Paraguai         5076670   7156293  2022  Brasil
# 6657                 Uruguai          637117    997367  2022  Brasil
# 6658                   Haiti          553503    741014  2022  Brasil
# 6659          Estados Unidos          220373    447893  2022  Brasil
# 6660                   China          105395    404647  2022  Brasil
# 6661             Reino Unido           18835    138154  2022  Brasil
# 6662                  Rússia           66046    118618  2022  Brasil
# 6663  Emirados Arabes Unidos            4781     85465  2022  Brasil
# 6664                   Japão           37324     82208  2022  Brasil
# 6665                 Curaçao           40673     66950  2022  Brasil
#
#          Tipo Vinho        Tipo   vl_litro
# 6656  Vinho De Mesa  Exportação   1.409643
# 6657  Vinho De Mesa  Exportação   1.565438
# 6658  Vinho De Mesa  Exportação   1.338771
# 6659  Vinho De Mesa  Exportação   2.032431
# 6660  Vinho De Mesa  Exportação   3.839338
# 6661  Vinho De Mesa  Exportação   7.334962
# 6662  Vinho De Mesa  Exportação   1.795991
# 6663  Vinho De Mesa  Exportação  17.875967
# 6664  Vinho De Mesa  Exportação   2.202551
# 6665  Vinho De Mesa  Exportação   1.646055

# %%
# rows_with_zeros = df[]
rows_with_zeros = (vinhos_de_mesa == 0).any(axis=1)

df2 = vinhos_de_mesa[~rows_with_zeros]
df2 = df2[df2['Destino'] == 'Paraguai']
# df2 = df2[df2['Ano'] >= 2014]
df2.head()
# Out:
#       Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 0    Paraguai           89846     23980  1970  Brasil  Vinho De Mesa
# 128  Paraguai          237805     64075  1971  Brasil  Vinho De Mesa
# 256  Paraguai          291625     84402  1972  Brasil  Vinho De Mesa
# 384  Paraguai          332433    115041  1973  Brasil  Vinho De Mesa
# 512  Paraguai          243294    119429  1974  Brasil  Vinho De Mesa
#
#            Tipo
# 0    Exportação
# 128  Exportação
# 256  Exportação
# 384  Exportação
# 512  Exportação

# %%
sns.lineplot(data=df2, x='Ano', y='Valor U$')
plt.title('Exportação para o Paraguai')
# Out:
# Text(0.5, 1.0, 'Exportação para o Paraguai')

# %%
# rows_with_zeros = df[]
rows_with_zeros = (vinhos_de_mesa == 0).any(axis=1)

df2 = vinhos_de_mesa[~rows_with_zeros]
df2 = df2[df2['Destino'] == 'Paraguai']
df2 = df2[df2['Ano'] >= 2014]
df2.head()
sns.lineplot(data=df2, x='Ano', y='Valor U$')
plt.title('Exportação para o Paraguai')
# Out:
# Text(0.5, 1.0, 'Exportação para o Paraguai')

# %%
print(f"MEAN - U$ {vinhos_de_mesa['Valor U$'].mean():.2f}")
# Out:
# MEAN - U$ 35715.80

# %%
df2 = vinhos_de_mesa[~rows_with_zeros]
df2 = df2[df2['Destino'] == 'Paraguai']
# df2 = df2[df2['Ano'] >= 2020]
df2['Variação Percentual'] = df2['Valor U$'].pct_change() * 100

df2['Variação Percentual'] = df2['Variação Percentual'].fillna(0)
# Formate os valores com duas casas decimais
df2['Variação Percentual'] = df2['Variação Percentual'].round(2)

df2.head()
# Out:
#       Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 0    Paraguai           89846     23980  1970  Brasil  Vinho De Mesa
# 128  Paraguai          237805     64075  1971  Brasil  Vinho De Mesa
# 256  Paraguai          291625     84402  1972  Brasil  Vinho De Mesa
# 384  Paraguai          332433    115041  1973  Brasil  Vinho De Mesa
# 512  Paraguai          243294    119429  1974  Brasil  Vinho De Mesa
#
#            Tipo  Variação Percentual
# 0    Exportação                 0.00
# 128  Exportação               167.20
# 256  Exportação                31.72
# 384  Exportação                36.30
# 512  Exportação                 3.81

# %%
# !pip install plotly==5.17.0
# Out:
# install: missing destination file operand after 'plotly==5.17.0'
# Try 'install --help' for more information.

# %%
import plotly.express as px

# %%
# Exemplo de como usar o plotly
# fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])
# fig.write_html('first_figure.html', auto_open=True)
# fig.show()

# %%
cascata = df2.iloc[-10:]
cascata
# Out:
#        Destino  Quantidade (L)  Valor U$   Ano  Origem     Tipo Vinho  \
# 5507  Paraguai          481564    680828  2013  Brasil  Vinho De Mesa
# 5633  Paraguai          521847    908028  2014  Brasil  Vinho De Mesa
# 5760  Paraguai          495428    741370  2015  Brasil  Vinho De Mesa
# 5888  Paraguai          985739   1655417  2016  Brasil  Vinho De Mesa
# 6016  Paraguai         2393468   4274650  2017  Brasil  Vinho De Mesa
# 6144  Paraguai         3234168   5494321  2018  Brasil  Vinho De Mesa
# 6272  Paraguai         2419537   3826587  2019  Brasil  Vinho De Mesa
# 6400  Paraguai         3299013   3869243  2020  Brasil  Vinho De Mesa
# 6528  Paraguai         6522527   7192362  2021  Brasil  Vinho De Mesa
# 6656  Paraguai         5076670   7156293  2022  Brasil  Vinho De Mesa
#
#             Tipo  Variação Percentual
# 5507  Exportação                58.97
# 5633  Exportação                33.37
# 5760  Exportação               -18.35
# 5888  Exportação               123.29
# 6016  Exportação               158.22
# 6144  Exportação                28.53
# 6272  Exportação               -30.35
# 6400  Exportação                 1.11
# 6528  Exportação                85.89
# 6656  Exportação                -0.50

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Waterfall(
    x=cascata['Ano'],
    y=cascata['Variação Percentual'],
    text=cascata['Variação Percentual'],
    textposition = "outside",
    ))

fig.update_layout(
        title = "Exportação para o Paraguai nos ulitmos 10 anos",
        showlegend = True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52849c35-7e59-443b-9d18-44df08ec0881" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52849c35-7e59-443b-9d18-44df08ec0881")) {                    Plotly.newPlot(                        "52849c35-7e59-443b-9d18-44df08ec0881",                        [{"connector":{"line":{"color":"rgb(63, 63, 63)"}},"text":[58.97,33.37,-18.35,123.29,158.22,28.53,-30.35,1.11,85.89,-0.5],"textposition":"outside","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[58.97,33.37,-18.35,123.29,158.22,28.53,-30.35,1.11,85.89,-0.5],"type":"waterfall"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# ## quanto o brasil exportou de vinho nos ultimos anos?
# ## qual a diferençao entre 1970 e 2022?
# ## qual a diferença entre 2010 e 2022?

# %%
agg_ano = dados.groupby(by='Ano')['Valor U$', 'Quantidade (L)'].sum()
agg_ano.head()
# Out:
# <ipython-input-59-1c7368dee2e6>:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#       Valor U$  Quantidade (L)
# Ano
# 1970     43884          141592
# 1971     87066          291096
# 1972    191784          504842
# 1973    609080         1120589
# 1974    600368          835988

# %%
sns.lineplot(agg_ano)
# Out:
# <Axes: xlabel='Ano'>

# %%
agg_ano['Vl Litro'] = agg_ano['Valor U$']/agg_ano['Quantidade (L)']

# %%
df = agg_ano.reset_index()
ano_inicial = df.loc[df['Ano'].idxmin()]['Ano']
ano_final = df.loc[df['Ano'].idxmax()]['Ano']

valor_inicial = df.loc[df['Ano'].idxmin()]['Valor U$']

# Encontre o valor de venda do último ano
valor_final = df.loc[df['Ano'].idxmax()]['Valor U$']

# Calcule a porcentagem de mudança
porcentagem_mudanca = ((valor_final - valor_inicial) / valor_inicial) * 100

print(f'A porcentagem de mudança entre o {ano_inicial:.0f} e o {ano_final:.0f} ano é: {porcentagem_mudanca:.2f}%')
# Out:
# A porcentagem de mudança entre o 1970 e o 2022 ano é: 312380.67%

# %%
# Out:
# 2013

# %%
# df = agg_ano.reset_index()
ano = 2022
ano_inicial = agg_ano.index[-10:][0]
ano_final = agg_ano.index[-10:][-1]

valor_inicial = agg_ano.loc[ano_inicial]['Valor U$']

# Encontre o valor de venda do último ano
valor_final = agg_ano.loc[ano_final]['Valor U$']

# Calcule a porcentagem de mudança
porcentagem_mudanca = ((valor_final - valor_inicial) / valor_inicial) * 100

print(f'A porcentagem de mudança entre o {ano_inicial:.0f} e o {ano_final:.0f} ano é: {porcentagem_mudanca:.2f}%')
# Out:
# A porcentagem de mudança entre o 2013 e o 2022 ano é: -1.41%

# %%
ultimos_10_anos = agg_ano.tail(10)

sns.lineplot(y=ultimos_10_anos['Valor U$'], x=ultimos_10_anos.index)
# Out:
# <Axes: xlabel='Ano', ylabel='Valor U$'>

# %%
sns.lineplot(ultimos_10_anos[['Valor U$','Quantidade (L)']])
# Out:
# <Axes: xlabel='Ano'>

# %%
sns.lineplot(y=agg_ano['Vl Litro'], x=agg_ano.index)
# Out:
# <Axes: xlabel='Ano', ylabel='Vl Litro'>
