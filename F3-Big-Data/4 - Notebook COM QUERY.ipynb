# %% [markdown]
# # Tech challenge - 03
#
# Notebook dedicado para reunir todas as querys utilizadas em nossas análises.
#
#
# Formulário usado para analise
# https://biblioteca.ibge.gov.br/visualizacao/instrumentos_de_coleta/doc5592.pdf

# %% [markdown]
# Tabela Principal
#
# A tabela principal surgiu a partir dos dados fornecidos pela base de dados do IBGE. Com ela, realizamos o tratamento e aplicamos a configuração para as 20 questões escolhidas.
#
# ```sql
# SELECT
#   sigla_uf AS UF,
#   capital,
#   CAST(a002 as int64) AS IDADE,
#   CASE
#     WHEN CAST(a003 AS int64) = 1 THEN 'Homem'
#   ELSE
#   'Mulher'
# END
#   AS SEXO,
#   CASE
#     WHEN CAST(a004 AS int64) = 1 THEN 'Branca'
#     WHEN CAST(a004 AS int64) = 2 THEN 'Preta'
#     WHEN CAST(a004 AS int64) = 3 THEN 'Amarela'
#     WHEN CAST(a004 AS int64) = 4 THEN 'Parda'
#     WHEN CAST(a004 AS int64) = 5 THEN 'Indígena'
# END
#   AS COR_RACA,
#   CASE
#     WHEN CAST(b0011 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0011 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Febre,
#   CASE
#     WHEN CAST(b0012 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0012 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   Tosse,
#   CASE
#     WHEN CAST(b0013 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0013 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Dor_de_garganta,
#   CASE
#     WHEN CAST(b0014 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0014 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Dificuldade_para_respirar,
#   CASE
#     WHEN CAST(b0015 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0015 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Dor_de_cabeca,
#   CASE
#     WHEN CAST(b0016 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0016 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Dor_no_peito,
#   CASE
#     WHEN CAST(b0017 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0017 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Nausea_enjoo,
#   CASE
#     WHEN CAST(b0018 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0018 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   Nariz_entupido_ou_escorrendo,
#   CASE
#     WHEN CAST(b0019 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b0019 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Fadiga_cansaco,
#   CASE
#     WHEN CAST(b00110 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b00110 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Dor_nos_olhos,
#   CASE
#     WHEN CAST(b00111 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b00111 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Perda_cheiro_ou_sabor,
#   CASE
#     WHEN CAST(b00112 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b00112 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Dor_muscular_dor_corpo,
#   CASE
#     WHEN CAST(b00113 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(b00113 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS Diarreia,
#   CASE
#     WHEN CAST(B002 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B002 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS FOI_ESTABELECIMENTO_SAUDE,
#   CASE
#     WHEN CAST(B0041 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0041 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS ATEND_PS_UBS_ESF,
#   CASE
#     WHEN CAST(B0042 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0042 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS ATEND_PS_SUS_UPA,
#   CASE
#     WHEN CAST(B0043 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0043 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS ATEND_HOSP_SUS,
#   CASE
#     WHEN CAST(B0044 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0044 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS ATEND_AMBU_CONSPRI_FA,
#   CASE
#     WHEN CAST(B0045 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0045 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS ATEND_PS_FA,
#   CASE
#     WHEN CAST(B0046 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0046 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS ATEND_HOSP_PRIV_FA,
#   CASE
#     WHEN CAST(B005 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B005 AS INT64) = 2 THEN 'Não'
#     WHEN CAST(B005 AS INT64) = 3 THEN 'Não foi atendido'
#   ELSE
#   'Ignorado'
# END
#   AS INTERNADO_UM_DIA_OU_MAIS,
#  CASE
#     WHEN CAST(B006 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B006 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS SEDADO_POS_INTERNACAO,
#     CASE
#     WHEN CAST(B007 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B007 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS PLANO_SAUDE,
#   CASE
#     WHEN CAST(B008 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B008 AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS FEZ_ALGUM_TESTE,
# CASE
#     WHEN CAST(B009A AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B009A AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS EXAME_COTONETE_SWAB,
#  CASE
#     WHEN CAST(B009B AS INT64) = 1 THEN 'Positivo'
#     WHEN CAST(B009B AS INT64) = 2 THEN 'Negativo'
#     WHEN CAST(B009B AS INT64) = 3 THEN 'Inconclusivo'
#     WHEN CAST(B009B AS INT64) = 4 THEN 'Ainda não recebeu o resultado'
#   ELSE
#   'Ignorado'
# END
#   AS RESULTADO_TESTE_COTONETE,
#
# CASE
#     WHEN CAST(B009C AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B009C AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS EXAME_SANGUE_FURO_DEDO,
#  CASE
#     WHEN CAST(B009D AS INT64) = 1 THEN 'Positivo'
#     WHEN CAST(B009D AS INT64) = 2 THEN 'Negativo'
#     WHEN CAST(B009D AS INT64) = 1 THEN 'Inconclusivo'
#     WHEN CAST(B009D AS INT64) = 2 THEN 'Ainda não recebeu o resultado'
#   ELSE
#   'Ignorado'
# END
#   AS RESULTADO_TESTE_SANGUE_FURO_DEDO,
# CASE
#     WHEN CAST(B009E AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B009E AS INT64) = 2 THEN 'Não'
#   ELSE
#   'Ignorado'
# END
#   AS EXAME_SANGUE_VEIA_BRACO,
#  CASE
#     WHEN CAST(B009F AS INT64) = 1 THEN 'Positivo'
#     WHEN CAST(B009F AS INT64) = 2 THEN 'Negativo'
#     WHEN CAST(B009F AS INT64) = 1 THEN 'Inconclusivo'
#     WHEN CAST(B009F AS INT64) = 2 THEN 'Ainda não recebeu o resultado'
#   ELSE
#   'Ignorado'
# END
#   AS RESULTADO_TESTE_SANGUE_VEIA_BRACO,
# CASE
#     WHEN CAST(B0101 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0101 AS INT64) = 2 THEN 'Não'
#     ELSE 'Ignorado'
# END AS DIAG_DIABETES,
# CASE
#     WHEN CAST(B0102 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0102 AS INT64) = 2 THEN 'Não'
#     ELSE 'Ignorado'
# END AS DIAG_HIPERTENSAO,
# CASE
#     WHEN CAST(B0103 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0103 AS INT64) = 2 THEN 'Não'
#     ELSE 'Ignorado'
# END AS DIAG_ASMA,
# CASE
#     WHEN CAST(B0104 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0104 AS INT64) = 2 THEN 'Não'
#     ELSE 'Ignorado'
# END AS DIAG_DOEN_CORACAO,
# CASE
#     WHEN CAST(B0105 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0105 AS INT64) = 2 THEN 'Não'
#     ELSE 'Ignorado'
# END AS DIAG_DEPRESSAO,
# CASE
#     WHEN CAST(B0106 AS INT64) = 1 THEN 'Sim'
#     WHEN CAST(B0106 AS INT64) = 2 THEN 'Não'
#     ELSE 'Ignorado'
# END AS DIAG_CANCER,
# CASE
#     WHEN CAST(B0106 AS INT64) = 1 THEN 'Não fez restrição, levou vida normal como antes da pandemia'
#     WHEN CAST(B0106 AS INT64) = 2 THEN 'Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas'
#     WHEN CAST(B0106 AS INT64) = 3 THEN 'Ficou em casa e só saiu em caso de necessidade básica (comprar comida, remédio, ir ao médico etc.)'
#     WHEN CAST(B0106 AS INT64) = 4 THEN 'Ficou rigorosamente isolado em casa'
#     ELSE 'Ignorado'
# END AS RESTRINGIU_CONTATO,
# CASE
#       WHEN CAST(B0041 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(B0041 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS BUSC_ATEND_POSTO,
#  CASE
#       WHEN CAST(B0042 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(B0042 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS BUSC_ATEND_PSOCORRO,
# CASE
#       WHEN CAST(B0043 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(B0043 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS BUSC_ATEND_HOPITAL,
# CASE
#       WHEN CAST(B0044 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(B0044 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS BUSC_ATEND_AMB,
# CASE
#       WHEN CAST(B0045 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(B0045 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS BUSC_ATEND_HOSP_PRIVADO,
# CASE
#       WHEN CAST(C001 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(C001 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS TRAB_SEM_PASSADA,
# CASE
#       WHEN CAST(C002 AS INT64) = 1 THEN 'Sim'
#       WHEN CAST(C002 AS INT64) = 2 THEN 'Não'
#       ELSE 'Ignorado'
# END AS AFAST_TRAB_SEM_PASSADA,
# CASE
#       WHEN CAST(C003 AS INT64) = 1 THEN 'Isolamento'
#       WHEN CAST(C003 AS INT64) = 2 THEN 'Féras ou folga'
#       WHEN CAST(C003 AS INT64) = 3 THEN 'Licença maternidade'
#       WHEN CAST(C003 AS INT64) = 4 THEN 'Licença remunerada por motivo de saúde'
#       WHEN CAST(C003 AS INT64) = 5 THEN 'Outro tipo de licença remunerada'
#       WHEN CAST(C003 AS INT64) = 6 THEN 'Afastamento do próprio negócio'
#       WHEN CAST(C003 AS INT64) = 7 THEN 'Fatores ocasionais ('
#       WHEN CAST(C003 AS INT64) = 8 THEN 'Outro motivo'
#       ELSE 'Ignorado'
# END AS MOT_AFASTAMENTO,
# CASE
#       WHEN CAST(C007 AS INT64) = 1 THEN 'Trabalhador doméstico'
#       WHEN CAST(C007 AS INT64) = 2 THEN 'Militar do exército'
#       WHEN CAST(C007 AS INT64) = 3 THEN 'Policial militar ou bombeiro militar'
#       WHEN CAST(C007 AS INT64) = 4 THEN 'Empregado do setor privado'
#       WHEN CAST(C007 AS INT64) = 5 THEN 'Outro tipo de licença remunerada'
#       WHEN CAST(C007 AS INT64) = 6 THEN 'Empregador'
#       WHEN CAST(C007 AS INT64) = 7 THEN 'Conta própria'
#       WHEN CAST(C007 AS INT64) = 8 THEN 'Trabalhador não remunerado'
#       WHEN CAST(C007 AS INT64) = 9 THEN 'Estava fora do mercado de trabalho'
#       ELSE 'Ignorado'
# END AS TINHA_TIPO_TRABALHO,
# CASE
#       WHEN CAST(C007C AS INT64) = 1 THEN 'Empregado doméstico(em domicílios particulares)'
#       WHEN CAST(C007C AS INT64) = 2 THEN 'Faxineiro (em empresa pública ou privada)'
#       WHEN CAST(C007C AS INT64) = 3 THEN 'Auxiliar de escritório'
#       WHEN CAST(C007C AS INT64) = 4 THEN 'Secretária, recepcionista'
#       WHEN CAST(C007C AS INT64) = 5 THEN 'Operador de Telemarketing'
#       WHEN CAST(C007C AS INT64) = 6 THEN 'Comerciante'
#       WHEN CAST(C007C AS INT64) = 7 THEN 'Balconista, vendedor de loja'
#       WHEN CAST(C007C AS INT64) = 8 THEN 'Vendedor a domicílio'
#       WHEN CAST(C007C AS INT64) = 9 THEN 'Vendedor ambulante'
#       WHEN CAST(C007C AS INT64) = 10 THEN 'Cozinheiro e garçom'
#       WHEN CAST(C007C AS INT64) = 11 THEN 'Padeiro, açougueiro e doceiro'
#       WHEN CAST(C007C AS INT64) = 12 THEN 'Agricultor, criador de animais'
#       WHEN CAST(C007C AS INT64) = 13 THEN 'Auxiliar da agropecuária'
#       WHEN CAST(C007C AS INT64) = 14 THEN 'Motorista de aplicativo'
#       WHEN CAST(C007C AS INT64) = 15 THEN 'Caminhoneiro'
#       WHEN CAST(C007C AS INT64) = 16 THEN 'Motoboy'
#       WHEN CAST(C007C AS INT64) = 17 THEN 'Entregador de mercadorias'
#       WHEN CAST(C007C AS INT64) = 18 THEN 'Pedreiro, servente de pedreiro'
#       WHEN CAST(C007C AS INT64) = 19 THEN 'Mecânico de veículos, máquinas industriais'
#       WHEN CAST(C007C AS INT64) = 20 THEN 'Artesão, costureiro e sapateiro'
#       WHEN CAST(C007C AS INT64) = 21 THEN 'Cabeleireiro, manicure e afins'
#       WHEN CAST(C007C AS INT64) = 22 THEN 'Operador de máquinas, montador na indústria'
#       WHEN CAST(C007C AS INT64) = 23 THEN 'Auxiliar de produção, de carga e descarga'
#       WHEN CAST(C007C AS INT64) = 24 THEN 'Professor da educação infantil'
#       WHEN CAST(C007C AS INT64) = 25 THEN 'Pedagogo, professor de idiomas, música, arte e reforço escolar'
#       WHEN CAST(C007C AS INT64) = 26 THEN 'Médico, enfermeiro, profissionais de saúde de nível superior'
#       WHEN CAST(C007C AS INT64) = 27 THEN 'Técnico, profissional da saúde de nível médio'
#       WHEN CAST(C007C AS INT64) = 28 THEN 'Cuidador de crianças, doentes ou idosos'
#       WHEN CAST(C007C AS INT64) = 29 THEN 'Segurança, vigilante, outro trabalhador dos serviços de proteção'
#       WHEN CAST(C007C AS INT64) = 30 THEN 'Policial civil'
#       WHEN CAST(C007C AS INT64) = 31 THEN 'Porteiro, zelador'
#       WHEN CAST(C007C AS INT64) = 32 THEN 'Artista, religioso (padre, pastor etc.)'
#       WHEN CAST(C007C AS INT64) = 33 THEN 'Diretor, gerente, cargo político ou comissionado'
#       WHEN CAST(C007C AS INT64) = 34 THEN 'Outra profissão de nível superior (advogado, engenheiro, contador, jornalista etc.)'
#       WHEN CAST(C007C AS INT64) = 35 THEN 'Outro técnico ou profissional de nível médio'
#       WHEN CAST(C007C AS INT64) = 36 THEN 'Outros'
#       ELSE 'Ignorado'
# END AS TIPO_TRABALHO,
# CASE
#       WHEN CAST(C007D AS INT64) = 1 THEN 'Agricultura, pecuária'
#       WHEN CAST(C007D AS INT64) = 2 THEN 'Extração de petróleo, carvão mineral'
#       WHEN CAST(C007D AS INT64) = 3 THEN 'Indústria da transformação'
#       WHEN CAST(C007D AS INT64) = 4 THEN 'Fornecimento de eletricidade e gás'
#       WHEN CAST(C007D AS INT64) = 5 THEN 'Construção'
#       WHEN CAST(C007D AS INT64) = 6 THEN 'Comércio no atacado e varejo'
#       WHEN CAST(C007D AS INT64) = 7 THEN 'Balconista, vendedor de loja'
#       WHEN CAST(C007D AS INT64) = 8 THEN 'Transporte de passageiros'
#       WHEN CAST(C007D AS INT64) = 9 THEN 'Transporte de mercadorias'
#       WHEN CAST(C007D AS INT64) = 10 THEN 'Correios, serviços de entregas'
#       WHEN CAST(C007D AS INT64) = 11 THEN 'Hospedagem (hotéis, pousadas etc.)'
#       WHEN CAST(C007D AS INT64) = 12 THEN 'Serviço de alimentação'
#       WHEN CAST(C007D AS INT64) = 13 THEN 'Informação e comunicação (jornais, rádio)'
#       WHEN CAST(C007D AS INT64) = 14 THEN 'Bancos, atividades financeiras e de seguros'
#       WHEN CAST(C007D AS INT64) = 15 THEN 'Atividades imobiliárias'
#       WHEN CAST(C007D AS INT64) = 16 THEN 'Escritórios de advocacia, engenharia, publicidade'
#       WHEN CAST(C007D AS INT64) = 17 THEN 'Atividades de locação de mão de obra'
#       WHEN CAST(C007D AS INT64) = 18 THEN 'Administração pública'
#       WHEN CAST(C007D AS INT64) = 19 THEN 'Educação'
#       WHEN CAST(C007D AS INT64) = 20 THEN 'Saúde humana e assistência social'
#       WHEN CAST(C007D AS INT64) = 21 THEN 'Organizações religiosas, sindicatos e associações'
#       WHEN CAST(C007D AS INT64) = 22 THEN 'Atividade artísticas, esportivas e de recreação'
#       WHEN CAST(C007D AS INT64) = 23 THEN 'Cabeleireiros, tratamento de beleza e serviços pessoais '
#       WHEN CAST(C007D AS INT64) = 24 THEN 'Serviço doméstico remunerado '
#       WHEN CAST(C007D AS INT64) = 25 THEN 'Outro'
#       ELSE 'Ignorado'
# END AS PRINC_ATIV_EMPRESA,
# CASE
#       WHEN C011A12 IS NULL THEN 0
#       ELSE C011A12
# END
# AS VALOR_DIN_RECEBIDO_REAL,
# CASE
#       WHEN C011A22 IS NULL THEN 0
#       ELSE C011A22
# END  AS VALOR_ESTIMADO_PRD_REAL,
# CASE
#   when CAST(B009B as int64) = 1 or cast(B009D as int64) = 1 or cast(B009F as int64) = 1 then 'Positivo'
#   else 'Negativo'
# end as COM_COVID
# FROM
#   basedosdados.br_ibge_pnad_covid.microdados
# where mes in (7,8,9);
# ```

# %% [markdown]
# ##Caracteristicas dos sintomas clínicos da população

# %% [markdown]
# ### Resultado da soma dos testes
# ```POSITIVOS: 25803 ```
# ```NEGATIVOS: 77899```

# %%
 SELECT
    SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Positivo' THEN 1 ELSE 0 END) AS Total_Positivo_Cotonete,
    SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Negativo' THEN 1 ELSE 0 END) AS Total_Negativo_Cotonete,
    SUM(CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Positivo' THEN 1 ELSE 0 END) AS Total_Positivo_SangueDedo,
    SUM(CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Negativo' THEN 1 ELSE 0 END) AS Total_Negativo_SangueDedo,
    SUM(CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Positivo' THEN 1 ELSE 0 END) AS Total_Positivo_SangueBraco,
    SUM(CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Negativo' THEN 1 ELSE 0 END) AS Total_Negativo_SangueBraco,
    SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Positivo' THEN 1 ELSE 0 END +
        CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Positivo' THEN 1 ELSE 0 END +
        CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Positivo' THEN 1 ELSE 0 END) AS Total_Geral_Positivo,
    SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Negativo' THEN 1 ELSE 0 END +
        CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Negativo' THEN 1 ELSE 0 END +
        CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Negativo' THEN 1 ELSE 0 END) AS Total_Geral_Negativo
FROM
    `onr-iauy.FIAP.IBGE`;

# %% [markdown]
# ###Paientes positivos por Estado
# ```sql
# SELECT
#     UF,
#     SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Positivo' THEN 1 ELSE 0 END) AS Total_Positivo_Cotonete,
#     SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Negativo' THEN 1 ELSE 0 END) AS Total_Negativo_Cotonete,
#     SUM(CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Positivo' THEN 1 ELSE 0 END) AS Total_Positivo_SangueDedo,
#     SUM(CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Negativo' THEN 1 ELSE 0 END) AS Total_Negativo_SangueDedo,
#     SUM(CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Positivo' THEN 1 ELSE 0 END) AS Total_Positivo_SangueBraco,
#     SUM(CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Negativo' THEN 1 ELSE 0 END) AS Total_Negativo_SangueBraco,
#     SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Positivo' THEN 1 ELSE 0 END +
#         CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Positivo' THEN 1 ELSE 0 END +
#         CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Positivo' THEN 1 ELSE 0 END) AS Total_Geral_Positivo,
#     SUM(CASE WHEN RESULTADO_TESTE_COTONETE = 'Negativo' THEN 1 ELSE 0 END +
#         CASE WHEN RESULTADO_TESTE_SANGUE_FURO_DEDO = 'Negativo' THEN 1 ELSE 0 END +
#         CASE WHEN RESULTADO_TESTE_SANGUE_VEIA_BRACO = 'Negativo' THEN 1 ELSE 0 END) AS Total_Geral_Negativo
# FROM
#     `onr-iauy.FIAP.IBGE`
# GROUP BY
#     UF;
# ```
# ![UF.png](data:image/png;base64,...)

# %% [markdown]
# ### Pacientes Positivos com algum tipo de ​doenças graves
#
#
# ```sql
# SELECT
#     SUM(CASE WHEN DIAG_DIABETES = 'Sim' AND COM_COVID = 'Positivo' THEN 1 ELSE 0 END) AS Total_Diabetes_Positivo,
#     SUM(CASE WHEN DIAG_HIPERTENSAO = 'Sim' AND COM_COVID = 'Positivo' THEN 1 ELSE 0 END) AS Total_Hipertensao_Positivo,
#     SUM(CASE WHEN DIAG_ASMA = 'Sim' AND COM_COVID = 'Positivo' THEN 1 ELSE 0 END) AS Total_Asma_Positivo,
#     SUM(CASE WHEN DIAG_DOEN_CORACAO = 'Sim' AND COM_COVID = 'Positivo' THEN 1 ELSE 0 END) AS Total_Doencas_Coracao_Positivo,
#     SUM(CASE WHEN DIAG_DEPRESSAO = 'Sim' AND COM_COVID = 'Positivo' THEN 1 ELSE 0 END) AS Total_Depressao_Positivo,
#     SUM(CASE WHEN DIAG_CANCER = 'Sim' AND COM_COVID = 'Positivo' THEN 1 ELSE 0 END) AS Total_Cancer_Positivo
# FROM
#     `onr-iauy.FIAP.IBGE`;
# ```

# %% [markdown]
# ### Os sinais e sintomas do coronavírus
#
# [Os sinais e sintomas do coronavírus](https://www.saude.ba.gov.br/temasdesaude/coronavirus/informacoes-sobre-a-covid-19/)

# %% [markdown]
# # Comportamento da população na época da Covid-19

# %% [markdown]
# ### Média de idade de pessoas positivadas com covid-19 presentes na base:
#
# ```sql
# SELECT ROUND(AVG(CAST(IDADE AS INT))) AS IDADEINT
# FROM `onr-fiap.FIAP.IBGE`
# WHERE COM_COVID = "Positivo";
# ```
#
# Média: 41.0
#
# https://jornal.usp.br/ciencias/media-de-idade-dos-primeiros-afetados-por-covid-19-no-brasil-e-menor-do-que-outros-paises/

# %% [markdown]
# # Média de idade de positivados por estado:
#
# ```sql
# SELECT UF, ROUND(AVG(IDADE)) AS IDADEINT FROM `onr-fiap.FIAP.IBGE` WHERE COM_COVID = "Positivo" GROUP BY UF
# ```
#
# Com médias próximas, os dois estados destaques são:
#
# RJ - 44
# https://g1.globo.com/rj/rio-de-janeiro/noticia/2020/03/17/confira-as-medidas-do-decreto-do-governo-do-rj-para-conter-o-coronavirus.ghtml
# <br>
# RN - 44
# https://g1.globo.com/rn/rio-grande-do-norte/noticia/2020/06/04/governo-do-rn-renova-decreto-de-isolamento-social-e-impoe-restricoes-a-circulacao-de-pessoas.ghtml

# %% [markdown]
# ### Dentre os presentes na base, quantos realizaram algum tipo de teste e o resultado foi positivo:
#
# ```sql
# SELECT SEXO, COUNT(*) AS POSITIVO FROM `onr-fiap.FIAP.IBGE` WHERE FEZ_ALGUM_TESTE = "Sim" AND COM_COVID = "Positivo" GROUP BY SEXO
#
# ```
#
# ![image.png](data:image/png;base64,...)
#
# https://ufmg.br/comunicacao/noticias/mulheres-sao-maioria-entre-os-brasileiros-infectados-pelo-coronavirus
#
# https://www.correiobraziliense.com.br/app/noticia/cidades/2020/07/24/interna_cidadesdf,874833/covid-no-df-mulheres-sao-maior-parte-de-infectados-mas-homens-morrem.shtml

# %% [markdown]
# ### Pessoas com acesso a plano de saúde
#
# ```sql
# SELECT COUNT(*) FROM `onr-fiap.FIAP.IBGE` WHERE COR_RACA = "Branca" AND PLANO_SAUDE = "Sim"
# ```
#
# Pessoas declaradas Brancas: 152396
#
# ```sql
# SELECT COUNT(*) FROM `onr-fiap.FIAP.IBGE` WHERE COR_RACA = "Preta" AND PLANO_SAUDE = "Sim"
# ```
# Pessoas declaradas Pretas: 16645
#
# ```sql
# SELECT COR_RACA, COUNT(*) FROM `onr-fiap.FIAP.IBGE` WHERE PLANO_SAUDE = "Sim" GROUP BY COR_RACA
# ```
#
# ![image.png](data:image/png;base64,...)
#
# https://www.gov.br/ans/pt-br/assuntos/noticias/covid-19/boletim-covid-19-ans-atualiza-dados-sobre-utilizacao-de-planos-na-pandemia

# %% [markdown]
# ### Pessoas que tinham algum tipo de trabalho e que testaram positivo para covid-19
#
# ```sql
# SELECT UF, COUNT(TIPO_TRABALHO) AS TRABALHO FROM `onr-fiap.FIAP.IBGE` WHERE COM_COVID = "Positivo" AND TIPO_TRABALHO != 'Ignorado' GROUP BY UF
# ```
#
# Estado com maior índice: ```SP - 970```
# <br>
# Estado com menor índice: ```RO - 200 ```
#
# ![image.png](data:image/png;base64,...)
#
# https://www.bbc.com/portuguese/brasil-57026232#:~:text=As%20dez%20profiss%C3%B5es%20mais%20atingidas,fisioterapeuta%2C%20agente%20comunit%C3%A1rio%20e%20recepcionista.
#
# https://www.paho.org/pt/noticias/2-9-2020-cerca-570-mil-profissionais-saude-se-infectaram-e-25-mil-morreram-por-covid-19
#
# https://www.scielo.br/j/rbso/a/CHvhLDtkH8WPmSygjHZgzNw/
#
# ```
# SELECT TIPO_TRABALHO, COUNT(TIPO_TRABALHO) AS TRABALHO FROM `onr-fiap.FIAP.IBGE` WHERE COM_COVID = "Positivo" AND TIPO_TRABALHO != 'Ignorado' GROUP BY TIPO_TRABALHO
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pessoas positivadas com covid-19 que restringiram contato
#
# ```sql
# SELECT RESTRINGIU_CONTATO, COUNT(*) AS RESTRINGIU FROM `onr-fiap.FIAP.IBGE` WHERE COM_COVID = "Positivo" GROUP BY RESTRINGIU_CONTATO
# ```
#
# ![image.png](data:image/png;base64,...)
#
# https://www.scielo.br/j/ress/a/fw8vPWhWV9j3ZyxMbVCZrMw/

# %% [markdown]
# # Características econômicas da sociedade

# %% [markdown]
# ##  Total pessoas sem renda = 752992
#
# ```sql
# select count(*)
# from `ace-tine-414617.postech.covid`
# where VALOR_DIN_RECEBIDO_REAL = 0 and VALOR_ESTIMADO_PRD_REAL = 0 ;
#
#
#
# SELECT 'SEM_RENDA' AS tipo_renda, COUNT(*) AS total
# FROM `ace-tine-414617.postech.covid`
# WHERE VALOR_DIN_RECEBIDO_REAL = 0 AND VALOR_ESTIMADO_PRD_REAL = 0
#
# UNION ALL
#
# SELECT 'COM_RENDA' AS tipo_renda, COUNT(*) AS total
# FROM `ace-tine-414617.postech.covid`
# WHERE VALOR_DIN_RECEBIDO_REAL > 0 OR VALOR_ESTIMADO_PRD_REAL > 0
# ```
#
# ## total da base = 1157984
#
# ```sql
# select count(*)
# from `ace-tine-414617.postech.covid` ;
# ```
#
#
# 65,03% não tem denda ou não declararam
#
#
# ### Salário médio por idade
#
# ```sql
# CREATE TEMP TABLE faixas_etarias AS
# SELECT
#   IDADE,
#   (VALOR_DIN_RECEBIDO_REAL+ VALOR_ESTIMADO_PRD_REAL) as VALOR_RECEBIDO,
#   CASE
#     WHEN IDADE BETWEEN 0 AND 11 THEN 'Criança'
#     WHEN IDADE BETWEEN 12 AND 20 THEN 'Adolescência'
#     WHEN IDADE BETWEEN 21 AND 65 THEN 'Adulto'
#     ELSE 'Velhice'
#   END AS faixa_etaria
# FROM
#   `ace-tine-414617.postech.covid`;
#
# # Calcule a média por faixa etária
# SELECT
#   faixa_etaria,
#   AVG(VALOR_RECEBIDO) AS valor_medio
# FROM
#     faixas_etarias
# GROUP BY
#   faixa_etaria;
# ```
#
# Criança
# 0.0
#
# Adolescência
# 106.6523126504718
#
# Adulto
# 1137.49
#
# Velhice
# 228.15
#
#
# ### salario medio dos que recebem
#
# ```sql
# CREATE TEMP TABLE faixas_etarias AS
# SELECT
#   IDADE,
#   (VALOR_DIN_RECEBIDO_REAL+ VALOR_ESTIMADO_PRD_REAL) as VALOR_RECEBIDO,
#   CASE
#     WHEN IDADE BETWEEN 0 AND 11 THEN 'Criança'
#     WHEN IDADE BETWEEN 12 AND 20 THEN 'Adolescência'
#     WHEN IDADE BETWEEN 21 AND 65 THEN 'Adulto'
#     ELSE 'Velhice'
#   END AS faixa_etaria
# FROM
#   `ace-tine-414617.postech.covid`
# ;
#
# # Calcule a média por faixa etária
# SELECT
#   faixa_etaria,
#   round(AVG(VALOR_RECEBIDO),2) AS valor_medio
# FROM
#     faixas_etarias
# where VALOR_RECEBIDO > 0
# GROUP BY
#   faixa_etaria;
#
# ```
#
#
# Adulto
# 2122.81
#
# Adolescência
# 948.94
#
#
# Velhice
# 2678.85

# %% [markdown]
# ### Top 10 das medias salariais com maior quantidade de entrevistados
#
# ``` sql
#  CREATE or replace TABLE `ace-tine-414617.postech.faixas_etarias` AS
#  SELECT
#    IDADE,
#    (VALOR_DIN_RECEBIDO_REAL+ VALOR_ESTIMADO_PRD_REAL) as VALOR_RECEBIDO,
#    CASE
#      WHEN IDADE BETWEEN 0 AND 11 THEN 'Criança'
#      WHEN IDADE BETWEEN 12 AND 20 THEN 'Adolescência'
#      WHEN IDADE BETWEEN 21 AND 65 THEN 'Adulto'
#      ELSE 'Velhice'
#    END AS faixa_etaria
#  FROM
#    `ace-tine-414617.postech.covid`
#  ;
#
# # Calcule a média por faixa etária
# SELECT
#   VALOR_RECEBIDO,
#   count(*) as  qtd
# FROM
#     `ace-tine-414617.postech.faixas_etarias`
# where faixa_etaria = 'Adulto'
# and VALOR_RECEBIDO > 0
# GROUP BY
#   VALOR_RECEBIDO
# order by qtd desc
# limit 10;
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Analise por estado
#
# ```sql
# select uf,
# round(avg(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL),0) as AVG_VALOR_RECEBIDO,
# count(*) as qtd,
# --APPROX_QUANTILES(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL, 4) AS quartis
# sum(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL) as TOTAL_RECEBIDO,
#
# from
# `ace-tine-414617.postech.covid`
# where (VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL) > 0
# group by uf
# order by AVG_VALOR_RECEBIDO desc
# ;
# ```

# %% [markdown]
# Total renda por estado com covid
#
# ```sql
# select uf,
# round(avg(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL),0) as AVG_VALOR_RECEBIDO,
# --APPROX_QUANTILES(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL, 4) AS quartis
# sum(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL) as TOTAL_RECEBIDO,
# count(COM_COVID) as total_com_covid
# from
# `ace-tine-414617.postech.covid`
# where COM_COVID = 'Positivo'
# and (VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL) > 0
# group by uf
# order by total_com_covid desc
# ;
# ```

# %% [markdown]
# Agrupamento de pessoas com o mesmo salário com covid
#
# ```sql
# select
# (VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL) as total_recebido,
# count(COM_COVID) as total_com_covid
# from
# `ace-tine-414617.postech.covid`
# where COM_COVID = 'Positivo'
# and uf = 'SP'
# group by total_recebido
# order by total_com_covid desc
# ;
# ```

# %% [markdown]
# Analise de profissão com covid e média salarial
#
# ```sql
# select
# TIPO_TRABALHO, PRINC_ATIV_EMPRESA,
# ROUND(AVG(VALOR_DIN_RECEBIDO_REAL+VALOR_ESTIMADO_PRD_REAL), 0) as MEDIA_RECEBIDO,
# COUNT(*) QTD
# from
# `ace-tine-414617.postech.covid`
# where COM_COVID = 'Positivo'
# --and uf = 'SP'
# group by TIPO_TRABALHO, PRINC_ATIV_EMPRESA
# order by QTD desc
# ```
