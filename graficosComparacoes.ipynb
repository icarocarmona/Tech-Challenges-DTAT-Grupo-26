# %% [markdown]
# <a href="https://colab.research.google.com/github/icarocarmona/tech_challenge_f1/blob/main/graficosComparacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análises

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/icarocarmona/tech_challenge_f1/main/dados/trusted/dados_de_vinhos.csv", sep=";" )
dados
# Out:
#                               Destino  Quantidade (L)  Valor U$   Ano  Origem  \
# 0                           Outros(1)            5132      3208  1970  Brasil
# 1                            Paraguai             415       152  1970  Brasil
# 2                             Bolívia              36        24  1970  Brasil
# 3                              Vietnã               0         0  1970  Brasil
# 4                              Líbano               0         0  1970  Brasil
# ...                               ...             ...       ...   ...     ...
# 25276                 Guiana Francesa               0         0  2022  Brasil
# 25277                       Guadalupe               0         0  2022  Brasil
# 25278                         Georgia               0         0  2022  Brasil
# 25279                            Gana               0         0  2022  Brasil
# 25280  Provisão de Navios e Aeronaves               0         0  2022  Brasil
#
#        Tipo Vinho        Tipo
# 0      Espumantes  Exportação
# 1      Espumantes  Exportação
# 2      Espumantes  Exportação
# 3      Espumantes  Exportação
# 4      Espumantes  Exportação
# ...           ...         ...
# 25276        Uvas  Exportação
# 25277        Uvas  Exportação
# 25278        Uvas  Exportação
# 25279        Uvas  Exportação
# 25280        Uvas  Exportação
#
# [25281 rows x 7 columns]

# %%
top_10_paises = dados.groupby(by='Destino')['Quantidade (L)'].sum().sort_values(ascending=False).head(10).index
top_10_paises
# Out:
# Index(['Países Baixos', 'Estados Unidos', 'Reino Unido', 'Paraguai', 'Japão',
#        'Argentina', 'Rússia', 'Alemanha, República Democrática', 'Canadá',
#        'Noruega'],
#       dtype='object', name='Destino')

# %%
destinosTop10 = dados[dados['Destino'].isin(top_10_paises)]
destinosTop10
# Out:
#                                Destino  Quantidade (L)  Valor U$   Ano  \
# 1                             Paraguai             415       152  1970
# 5                              Noruega               0         0  1970
# 18                               Japão               0         0  1970
# 44                         Reino Unido               0         0  1970
# 72                           Argentina               0         0  1970
# ...                                ...             ...       ...   ...
# 25161  Alemanha, República Democrática          559012   1213303  2022
# 25162                          Noruega          381020    594883  2022
# 25187                            Japão             377      1270  2022
# 25228                         Paraguai               0         0  2022
# 25231                      Reino Unido               0         0  2022
#
#        Origem  Tipo Vinho        Tipo
# 1      Brasil  Espumantes  Exportação
# 5      Brasil  Espumantes  Exportação
# 18     Brasil  Espumantes  Exportação
# 44     Brasil  Espumantes  Exportação
# 72     Brasil  Espumantes  Exportação
# ...       ...         ...         ...
# 25161  Brasil        Uvas  Exportação
# 25162  Brasil        Uvas  Exportação
# 25187  Brasil        Uvas  Exportação
# 25228  Brasil        Uvas  Exportação
# 25231  Brasil        Uvas  Exportação
#
# [1802 rows x 7 columns]

# %%
destinosTop10_Ano = destinosTop10[destinosTop10['Ano'] >= 2007]
destinosTop10_Ano
# Out:
#                                Destino  Quantidade (L)  Valor U$   Ano  \
# 3737                    Estados Unidos           21400     86898  2007
# 3741                       Reino Unido            3166      9260  2007
# 3742                          Paraguai            3455      6958  2007
# 3746                             Japão            1395      5314  2007
# 3759                           Noruega               0         0  2007
# ...                                ...             ...       ...   ...
# 25161  Alemanha, República Democrática          559012   1213303  2022
# 25162                          Noruega          381020    594883  2022
# 25187                            Japão             377      1270  2022
# 25228                         Paraguai               0         0  2022
# 25231                      Reino Unido               0         0  2022
#
#        Origem  Tipo Vinho        Tipo
# 3737   Brasil  Espumantes  Exportação
# 3741   Brasil  Espumantes  Exportação
# 3742   Brasil  Espumantes  Exportação
# 3746   Brasil  Espumantes  Exportação
# 3759   Brasil  Espumantes  Exportação
# ...       ...         ...         ...
# 25161  Brasil        Uvas  Exportação
# 25162  Brasil        Uvas  Exportação
# 25187  Brasil        Uvas  Exportação
# 25228  Brasil        Uvas  Exportação
# 25231  Brasil        Uvas  Exportação
#
# [544 rows x 7 columns]

# %%
import seaborn as sns

# %%
sns.catplot(data=destinosTop10_Ano, x="Ano", y="Quantidade (L)", col="Destino", kind="bar")
